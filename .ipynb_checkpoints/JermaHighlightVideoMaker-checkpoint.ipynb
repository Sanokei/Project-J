# %%
# !pip install tensorflow
# !pip install tensorflow-hub
# !pip install tensorflow-text

# %%
# !pip install youtube-dl
# !pip install datetime

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
import os
from datetime import timedelta, datetime, date, time

import youtube_dl
import requests
import re
import uuid
from youtube_transcript_api import YouTubeTranscriptApi
import json

# %%
model_path = r''+os.getcwd()+'\\jerma_model\\'
model = tf.keras.models.load_model(model_path)
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.

# %%
# Testing
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None,)]            0
# __________________________________________________________________________________________________
# keras_layer (KerasLayer)        {'input_mask': (None 0           input[0][0]
# __________________________________________________________________________________________________
# keras_layer_1 (KerasLayer)      {'default': (None, 7 109482241   keras_layer[0][0]
#                                                                  keras_layer[0][1]
#                                                                  keras_layer[0][2]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 768)          0           keras_layer_1[0][13]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         dropout[0][0]
# ==================================================================================================
# Total params: 109,483,010
# Trainable params: 769
# Non-trainable params: 109,482,241
# __________________________________________________________________________________________________

# %%
cand = {"[Laughter]":"","[Music]":"","[Applause]":""}
mid_bit = "="
drift = 0.0

# %%
def createTimestampFile(youtubeID):
    global mid_bit
    
    name = "timestamp" + mid_bit
    index = 1
    url = "https://www.youtube.com/watch?v={}".format(youtubeID)
    change = mid_bit+ str(uuid.uuid4().hex)
    ydl = youtube_dl.YoutubeDL({'writesubtitles': True, 'allsubtitles': True, 'writeautomaticsub': True})
    res = ydl.extract_info(url, download=False)
    if not os.path.exists(os.getcwd() + "\\temp\\" + name + res.get("id", None) + ".txt"):
        change = ""
    if res['requested_subtitles'] and res['requested_subtitles']['en']:
        print('Grabbing vtt file from ' + res['requested_subtitles']['en']['url'])
        response = requests.get(res['requested_subtitles']['en']['url'], stream=True)
        '''
        Regex:
        \d = digit
        {} = {# of digits}
        \W = any word character
        \s = white spaces
        '''
        timeStampRegex = re.compile(r'\d{2}\W\d{2}\W\d{2}\W\d{3}\s\W{3}\s\d{2}\W\d{2}\W\d{2}\W\d{3}')
        print(response.text)
        new = timeStampRegex.findall(response.text)
#         f1 = open(name + res.get("id", None) + change + ".txt", "a+")
#         f1.write("{")
#         f1.close()
        if new is None:
            print("Found instance of none")
        else:
            for i in new:
                i = re.sub(" --> ","\",\"end\":\"",i)
                # line = '\"'+str(index)+"\":"+"{\"start\":" + str(i)+"},\n"
                line = "{\"start\":\"" + str(i)+"\"}\n"
                # print(line)
                f1 = open(os.getcwd() + "\\temp\\" + name + res.get("id", None) + change + ".txt", "a+")
                f1.write(line)
                f1.close()
                index += 1
#         f1 = open(name + res.get("id", None) + change + ".txt", "a+")
#         f1.write("}")
#         f1.close()
        if len(res['subtitles']) > 0:
            print('manual captions')
        else:
            print('automatic_captions')
            
        return name + res.get("id", None) + change + ".txt"
    else:
        print('Youtube Video does not have any english captions')
        return None

# %%
def createTranscriptFile(video_id):
    global mid_bit
    global cand
    
    name = "trans" + mid_bit
    change = mid_bit+ str(uuid.uuid4().hex)
    if not os.path.exists(os.getcwd() + "\\temp\\" + name + video_id + ".txt"):
        change = ""
    file_name = name + video_id + change

    transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
    try:
        transcript = transcript_list.find_manually_created_transcript(['en'])
    except Exception:
        transcript = transcript_list.find_generated_transcript(['en'])
    tran = transcript.fetch()
    
    with open(os.getcwd() + "\\temp\\" +'{}.txt'.format(file_name),'w+') as file:
        for line in tran:
            newLine = line.get("text")
            i = "" if not [k for k,v in cand.items() if line.get("text") == k] else [k for k,v in cand.items() if line.get("text") == k][0]
            newLine = line.get("text").replace(i,"")
            newLine = newLine.replace("\n","")
            print(newLine)
            if newLine.strip():
                file.write(newLine+"\n")
    return file_name + ".txt"

# %%
def createCommandFile(timestamp_file_name,trans_file_name):
    global mid_bit
    global drift
    
    video_id = timestamp_file_name.split(mid_bit)[1]
    name = "command"+ mid_bit
    change = mid_bit+ str(uuid.uuid4().hex)
    if not os.path.exists(os.getcwd() + "\\temp\\" + name + video_id + ".txt"):
        change = ""
    file_name = name + video_id + change
    
    with open(os.getcwd() + "\\temp\\" +timestamp_file_name,"r") as timestamp_file:
        timestamp_allLines = timestamp_file.readlines()
    
    with open(os.getcwd() + "\\temp\\" +trans_file_name,"r") as trans_file:
        trans_allLines = trans_file.readlines()
    
    timestamp_max_line = len(timestamp_allLines)
    trans_max_line = len(trans_allLines)
    print(timestamp_max_line)
    print(trans_max_line )
    for line in range(trans_max_line):
        print(timestamp_allLines[line])
        time_dic = json.loads(timestamp_allLines[line])
        
        if(not trans_allLines[line].strip()):
            continue
            
        text = trans_allLines[line]
        predict = model.predict([text])
        print(predict)
        if predict > 0.2 + drift:
            with open(os.getcwd() + "\\temp\\" +'{}.txt'.format(file_name),'a+') as command_file:
                command_file.write(get_command(youtubeID,time_dic["start"],time_dic["end"],str(line)+ ".mp4"))   
    
    return file_name + ".txt"

# %%
def get_command(url,start,end,output_dir):
    # format of start and end
    ## e.g 
    # format needed
    ## 00:13:00.00
    # format style: url duration start
    duration = datetime.combine(date.min, time.fromisoformat(end)) - datetime.combine(date.min, time.fromisoformat(start))
    return "ffmpeg $(youtube-dl -g '{}' | sed 's/^/-ss {} -i /') -t {} -c copy {}\n".format(
        url,duration,start,output_dir
    )

# %%
if __name__ == '__main__':
    youtubeID = "DDg9TGHoPUU"
    timestamp_file_name = createTimestampFile(youtubeID)
    trans_file_name = createTranscriptFile(youtubeID)
    command_file_name = createCommandFile(timestamp_file_name,trans_file_name)
# Out:
# [youtube] DDg9TGHoPUU: Downloading webpage
# Grabbing vtt file from https://www.youtube.com/api/timedtext?v=DDg9TGHoPUU&asr_langs=de%2Cen%2Ces%2Cfr%2Cit%2Cja%2Cko%2Cnl%2Cpt%2Cru&caps=asr&exp=xftt%2Cxctw&xoaf=4&hl=en&ip=0.0.0.0&ipbits=0&expire=1629181838&sparams=ip%2Cipbits%2Cexpire%2Cv%2Casr_langs%2Ccaps%2Cexp%2Cxoaf&signature=BED5369F3C1B5C22831C25756CFEEE0D4DE2D421.0626DC01399FEE8B11F63E1452D40BCC14B3B2B5&key=yt8&kind=asr&lang=en&tlang=en&fmt=vtt
# WEBVTT
# Kind: captions
# Language: en
#
# 00:00:15.839 --> 00:00:16.630 align:start position:0%
#
# all<00:00:15.920><c> right</c>
#
# 00:00:16.630 --> 00:00:16.640 align:start position:0%
# all right
#
#
# 00:00:16.640 --> 00:00:24.710 align:start position:0%
# all right
# hello<00:00:17.760><c> what</c><00:00:18.000><c> what</c><00:00:18.160><c> is</c><00:00:18.320><c> this</c>
#
# 00:00:24.710 --> 00:00:24.720 align:start position:0%
#
#
#
# 00:00:24.720 --> 00:00:34.069 align:start position:0%
#
# not<00:00:24.960><c> muted</c><00:00:26.000><c> wait</c><00:00:26.400><c> wait</c><00:00:28.840><c> wait</c>
#
# 00:00:34.069 --> 00:00:34.079 align:start position:0%
#
#
#
# 00:00:34.079 --> 00:00:35.430 align:start position:0%
#
# i<00:00:34.239><c> just</c><00:00:34.399><c> turned</c><00:00:34.640><c> the</c><00:00:34.719><c> stream</c><00:00:35.120><c> on</c><00:00:35.200><c> what</c><00:00:35.360><c> are</c><00:00:35.360><c> you</c>
#
# 00:00:35.430 --> 00:00:35.440 align:start position:0%
# i just turned the stream on what are you
#
#
# 00:00:35.440 --> 00:00:36.950 align:start position:0%
# i just turned the stream on what are you
# gonna<00:00:35.680><c> have</c><00:00:35.840><c> 20</c><00:00:36.000><c> minutes</c><00:00:36.239><c> before</c><00:00:36.480><c> my</c><00:00:36.640><c> solar</c>
#
# 00:00:36.950 --> 00:00:36.960 align:start position:0%
# gonna have 20 minutes before my solar
#
#
# 00:00:36.960 --> 00:00:39.110 align:start position:0%
# gonna have 20 minutes before my solar
# system<00:00:37.280><c> is</c><00:00:37.440><c> destroyed</c>
#
# 00:00:39.110 --> 00:00:39.120 align:start position:0%
# system is destroyed
#
#
# 00:00:39.120 --> 00:00:41.990 align:start position:0%
# system is destroyed
# oh<00:00:40.399><c> it's</c><00:00:40.559><c> like</c><00:00:40.719><c> we</c><00:00:40.960><c> just</c><00:00:41.360><c> i</c><00:00:41.520><c> just</c><00:00:41.680><c> turned</c><00:00:41.920><c> the</c>
#
# 00:00:41.990 --> 00:00:42.000 align:start position:0%
# oh it's like we just i just turned the
#
#
# 00:00:42.000 --> 00:00:43.750 align:start position:0%
# oh it's like we just i just turned the
# stream<00:00:42.320><c> on</c><00:00:42.480><c> you</c><00:00:42.559><c> have</c><00:00:42.719><c> 20</c><00:00:42.960><c> minutes</c><00:00:43.280><c> before</c><00:00:43.520><c> the</c>
#
# 00:00:43.750 --> 00:00:43.760 align:start position:0%
# stream on you have 20 minutes before the
#
#
# 00:00:43.760 --> 00:00:46.790 align:start position:0%
# stream on you have 20 minutes before the
# [ __ ]<00:00:44.239><c> solar</c><00:00:44.640><c> system</c><00:00:45.039><c> is</c><00:00:45.200><c> destroyed</c><00:00:45.680><c> jeremy</c>
#
# 00:00:46.790 --> 00:00:46.800 align:start position:0%
# [ __ ] solar system is destroyed jeremy
#
#
# 00:00:46.800 --> 00:00:51.510 align:start position:0%
# [ __ ] solar system is destroyed jeremy
# you're<00:00:47.039><c> five</c><00:00:47.360><c> minutes</c><00:00:47.760><c> late</c><00:00:49.760><c> no</c><00:00:50.000><c> audio</c>
#
# 00:00:51.510 --> 00:00:51.520 align:start position:0%
# you're five minutes late no audio
#
#
# 00:00:51.520 --> 00:00:53.990 align:start position:0%
# you're five minutes late no audio
# oh<00:00:51.680><c> there</c><00:00:51.840><c> we</c><00:00:51.920><c> go</c><00:00:52.559><c> everything</c><00:00:52.960><c> will</c><00:00:53.199><c> reset</c>
#
# 00:00:53.990 --> 00:00:54.000 align:start position:0%
# oh there we go everything will reset
#
#
# 00:00:54.000 --> 00:00:56.069 align:start position:0%
# oh there we go everything will reset
# allowing<00:00:54.399><c> you</c><00:00:54.559><c> to</c><00:00:54.719><c> continue</c><00:00:55.199><c> exploring</c><00:00:55.840><c> while</c>
#
# 00:00:56.069 --> 00:00:56.079 align:start position:0%
# allowing you to continue exploring while
#
#
# 00:00:56.079 --> 00:00:58.229 align:start position:0%
# allowing you to continue exploring while
# retaining<00:00:56.559><c> information</c><00:00:57.120><c> you</c><00:00:57.280><c> gathered</c>
#
# 00:00:58.229 --> 00:00:58.239 align:start position:0%
# retaining information you gathered
#
#
# 00:00:58.239 --> 00:00:59.510 align:start position:0%
# retaining information you gathered
# i<00:00:58.559><c> didn't</c><00:00:58.719><c> even</c><00:00:58.800><c> know</c><00:00:58.960><c> there</c><00:00:59.039><c> was</c><00:00:59.199><c> a</c><00:00:59.280><c> direct</c>
#
# 00:00:59.510 --> 00:00:59.520 align:start position:0%
# i didn't even know there was a direct
#
#
# 00:00:59.520 --> 00:01:01.510 align:start position:0%
# i didn't even know there was a direct
# today<00:01:00.000><c> i</c><00:01:00.079><c> had</c><00:01:00.239><c> no</c><00:01:00.399><c> idea</c><00:01:00.800><c> i</c><00:01:00.960><c> don't</c><00:01:01.039><c> even</c><00:01:01.199><c> watch</c>
#
# 00:01:01.510 --> 00:01:01.520 align:start position:0%
# today i had no idea i don't even watch
#
#
# 00:01:01.520 --> 00:01:03.510 align:start position:0%
# today i had no idea i don't even watch
# these
#
# 00:01:03.510 --> 00:01:03.520 align:start position:0%
# these
#
#
# 00:01:03.520 --> 00:01:05.429 align:start position:0%
# these
# by<00:01:03.680><c> repeating</c><00:01:04.080><c> these</c><00:01:04.320><c> cycles</c><00:01:05.199><c> you'll</c>
#
# 00:01:05.429 --> 00:01:05.439 align:start position:0%
# by repeating these cycles you'll
#
#
# 00:01:05.439 --> 00:01:07.429 align:start position:0%
# by repeating these cycles you'll
# gradually<00:01:06.000><c> unravel</c><00:01:06.479><c> the</c><00:01:06.640><c> mysteries</c><00:01:07.119><c> hidden</c>
#
# 00:01:07.429 --> 00:01:07.439 align:start position:0%
# gradually unravel the mysteries hidden
#
#
# 00:01:07.439 --> 00:01:10.230 align:start position:0%
# gradually unravel the mysteries hidden
# in<00:01:07.520><c> the</c><00:01:07.680><c> universe</c>
#
# 00:01:10.230 --> 00:01:10.240 align:start position:0%
# in the universe
#
#
# 00:01:10.240 --> 00:01:12.149 align:start position:0%
# in the universe
# wait<00:01:10.400><c> did</c><00:01:10.560><c> they</c><00:01:10.720><c> spoil</c><00:01:11.040><c> the</c><00:01:11.200><c> game</c><00:01:11.920><c> what</c>
#
# 00:01:12.149 --> 00:01:12.159 align:start position:0%
# wait did they spoil the game what
#
#
# 00:01:12.159 --> 00:01:14.310 align:start position:0%
# wait did they spoil the game what
# message<00:01:12.479><c> is</c><00:01:13.040><c> so</c><00:01:13.280><c> disheveled</c><00:01:13.920><c> right</c><00:01:14.080><c> now</c>
#
# 00:01:14.310 --> 00:01:14.320 align:start position:0%
# message is so disheveled right now
#
#
# 00:01:14.320 --> 00:01:17.030 align:start position:0%
# message is so disheveled right now
# i<00:01:14.640><c> haven't</c><00:01:14.799><c> even</c><00:01:14.960><c> brushed</c><00:01:15.200><c> my</c><00:01:15.439><c> teeth</c><00:01:15.680><c> yet</c><00:01:16.880><c> why</c>
#
# 00:01:17.030 --> 00:01:17.040 align:start position:0%
# i haven't even brushed my teeth yet why
#
#
# 00:01:17.040 --> 00:01:18.710 align:start position:0%
# i haven't even brushed my teeth yet why
# is<00:01:17.200><c> the</c><00:01:17.439><c> solar</c><00:01:17.759><c> system</c><00:01:18.080><c> trapped</c><00:01:18.400><c> in</c><00:01:18.560><c> an</c>
#
# 00:01:18.710 --> 00:01:18.720 align:start position:0%
# is the solar system trapped in an
#
#
# 00:01:18.720 --> 00:01:19.990 align:start position:0%
# is the solar system trapped in an
# endless<00:01:18.960><c> i</c><00:01:19.040><c> was</c><00:01:19.200><c> getting</c><00:01:19.360><c> out</c><00:01:19.520><c> i</c><00:01:19.680><c> was</c><00:01:19.759><c> getting</c>
#
# 00:01:19.990 --> 00:01:20.000 align:start position:0%
# endless i was getting out i was getting
#
#
# 00:01:20.000 --> 00:01:21.190 align:start position:0%
# endless i was getting out i was getting
# out<00:01:20.080><c> of</c><00:01:20.159><c> the</c><00:01:20.320><c> shower</c>
#
# 00:01:21.190 --> 00:01:21.200 align:start position:0%
# out of the shower
#
#
# 00:01:21.200 --> 00:01:22.550 align:start position:0%
# out of the shower
# and<00:01:21.360><c> somebody</c><00:01:21.680><c> just</c><00:01:21.840><c> goes</c><00:01:22.080><c> hey</c><00:01:22.240><c> dude</c><00:01:22.400><c> you're</c>
#
# 00:01:22.550 --> 00:01:22.560 align:start position:0%
# and somebody just goes hey dude you're
#
#
# 00:01:22.560 --> 00:01:24.230 align:start position:0%
# and somebody just goes hey dude you're
# missing<00:01:22.799><c> the</c><00:01:22.880><c> directly</c><00:01:23.520><c> acclaimed</c><00:01:23.920><c> outer</c>
#
# 00:01:24.230 --> 00:01:24.240 align:start position:0%
# missing the directly acclaimed outer
#
#
# 00:01:24.240 --> 00:01:26.230 align:start position:0%
# missing the directly acclaimed outer
# wilds<00:01:24.640><c> launches</c>
#
# 00:01:26.230 --> 00:01:26.240 align:start position:0%
# wilds launches
#
#
# 00:01:26.240 --> 00:01:29.749 align:start position:0%
# wilds launches
# summer<00:01:26.640><c> 2021.</c><00:01:27.439><c> i</c><00:01:27.520><c> don't</c><00:01:27.680><c> care</c>
#
# 00:01:29.749 --> 00:01:29.759 align:start position:0%
# summer 2021. i don't care
#
#
# 00:01:29.759 --> 00:01:31.350 align:start position:0%
# summer 2021. i don't care
# put<00:01:29.920><c> your</c><00:01:30.079><c> sleuthing</c><00:01:30.479><c> but</c><00:01:30.560><c> then</c><00:01:30.720><c> i</c><00:01:30.799><c> was</c><00:01:30.880><c> like</c><00:01:31.040><c> i</c>
#
# 00:01:31.350 --> 00:01:31.360 align:start position:0%
# put your sleuthing but then i was like i
#
#
# 00:01:31.360 --> 00:01:33.350 align:start position:0%
# put your sleuthing but then i was like i
# kind<00:01:31.520><c> of</c><00:01:31.680><c> do</c><00:01:32.000><c> two</c><00:01:32.240><c> classic</c><00:01:32.560><c> murder</c><00:01:32.960><c> mystery</c>
#
# 00:01:33.350 --> 00:01:33.360 align:start position:0%
# kind of do two classic murder mystery
#
#
# 00:01:33.360 --> 00:01:33.670 align:start position:0%
# kind of do two classic murder mystery
# games
#
# 00:01:33.670 --> 00:01:33.680 align:start position:0%
# games
#
#
# 00:01:33.680 --> 00:01:34.950 align:start position:0%
# games
# i<00:01:33.759><c> haven't</c><00:01:34.000><c> brushed</c><00:01:34.240><c> my</c><00:01:34.320><c> teeth</c><00:01:34.560><c> yet</c><00:01:34.720><c> i</c><00:01:34.799><c> got</c><00:01:34.880><c> up</c>
#
# 00:01:34.950 --> 00:01:34.960 align:start position:0%
# i haven't brushed my teeth yet i got up
#
#
# 00:01:34.960 --> 00:01:36.789 align:start position:0%
# i haven't brushed my teeth yet i got up
# like<00:01:35.119><c> 10</c><00:01:35.280><c> minutes</c><00:01:35.600><c> ago</c><00:01:36.000><c> did</c><00:01:36.159><c> not</c><00:01:36.320><c> wake</c><00:01:36.560><c> up</c><00:01:36.640><c> ten</c>
#
# 00:01:36.789 --> 00:01:36.799 align:start position:0%
# like 10 minutes ago did not wake up ten
#
#
# 00:01:36.799 --> 00:01:38.149 align:start position:0%
# like 10 minutes ago did not wake up ten
# minutes<00:01:37.040><c> ago</c>
#
# 00:01:38.149 --> 00:01:38.159 align:start position:0%
# minutes ago
#
#
# 00:01:38.159 --> 00:01:39.990 align:start position:0%
# minutes ago
# and<00:01:38.320><c> famicom</c><00:01:38.799><c> detective</c><00:01:39.200><c> club</c><00:01:39.520><c> the</c><00:01:39.600><c> girl</c><00:01:39.759><c> who</c>
#
# 00:01:39.990 --> 00:01:40.000 align:start position:0%
# and famicom detective club the girl who
#
#
# 00:01:40.000 --> 00:01:41.190 align:start position:0%
# and famicom detective club the girl who
# stands<00:01:40.240><c> behind</c><00:01:40.799><c> jim</c>
#
# 00:01:41.190 --> 00:01:41.200 align:start position:0%
# stands behind jim
#
#
# 00:01:41.200 --> 00:01:42.230 align:start position:0%
# stands behind jim
# get<00:01:41.280><c> me</c><00:01:41.360><c> out</c><00:01:41.439><c> of</c><00:01:41.520><c> here</c><00:01:41.600><c> deep</c><00:01:41.840><c> cuts</c><00:01:42.079><c> from</c>
#
# 00:01:42.230 --> 00:01:42.240 align:start position:0%
# get me out of here deep cuts from
#
#
# 00:01:42.240 --> 00:01:44.310 align:start position:0%
# get me out of here deep cuts from
# nintendo<00:01:42.720><c> history</c><00:01:43.439><c> are</c><00:01:43.600><c> coming</c><00:01:43.840><c> to</c><00:01:44.079><c> north</c>
#
# 00:01:44.310 --> 00:01:44.320 align:start position:0%
# nintendo history are coming to north
#
#
# 00:01:44.320 --> 00:01:46.950 align:start position:0%
# nintendo history are coming to north
# america<00:01:44.720><c> for</c><00:01:44.880><c> the</c><00:01:44.960><c> first</c><00:01:45.280><c> time</c>
#
# 00:01:46.950 --> 00:01:46.960 align:start position:0%
# america for the first time
#
#
# 00:01:46.960 --> 00:01:48.789 align:start position:0%
# america for the first time
# localized<00:01:47.520><c> in</c><00:01:47.680><c> english</c><00:01:48.000><c> and</c><00:01:48.159><c> modernized</c><00:01:48.720><c> for</c>
#
# 00:01:48.789 --> 00:01:48.799 align:start position:0%
# localized in english and modernized for
#
#
# 00:01:48.799 --> 00:01:50.710 align:start position:0%
# localized in english and modernized for
# the<00:01:48.960><c> nintendo</c><00:01:49.439><c> switch</c><00:01:49.759><c> system</c><00:01:50.159><c> what</c><00:01:50.320><c> game</c><00:01:50.560><c> is</c>
#
# 00:01:50.710 --> 00:01:50.720 align:start position:0%
# the nintendo switch system what game is
#
#
# 00:01:50.720 --> 00:01:50.950 align:start position:0%
# the nintendo switch system what game is
# this
#
# 00:01:50.950 --> 00:01:50.960 align:start position:0%
# this
#
#
# 00:01:50.960 --> 00:01:54.310 align:start position:0%
# this
# defense<00:01:51.759><c> drama</c><00:01:52.880><c> and</c><00:01:53.040><c> twists</c><00:01:53.439><c> and</c><00:01:53.600><c> turns</c><00:01:53.920><c> await</c>
#
# 00:01:54.310 --> 00:01:54.320 align:start position:0%
# defense drama and twists and turns await
#
#
# 00:01:54.320 --> 00:01:54.550 align:start position:0%
# defense drama and twists and turns await
# at
#
# 00:01:54.550 --> 00:01:54.560 align:start position:0%
# at
#
#
# 00:01:54.560 --> 00:01:57.270 align:start position:0%
# at
# famicom<00:01:55.200><c> detective</c><00:01:55.759><c> club</c><00:01:56.799><c> you'll</c><00:01:56.960><c> be</c><00:01:57.040><c> on</c><00:01:57.200><c> the</c>
#
# 00:01:57.270 --> 00:01:57.280 align:start position:0%
# famicom detective club you'll be on the
#
#
# 00:01:57.280 --> 00:01:57.990 align:start position:0%
# famicom detective club you'll be on the
# edge<00:01:57.439><c> of</c><00:01:57.520><c> your</c><00:01:57.680><c> seat</c>
#
# 00:01:57.990 --> 00:01:58.000 align:start position:0%
# edge of your seat
#
#
# 00:01:58.000 --> 00:01:59.270 align:start position:0%
# edge of your seat
# of<00:01:58.079><c> nintendo</c><00:01:58.560><c> you'll</c><00:01:58.719><c> see</c><00:01:58.880><c> these</c><00:01:59.040><c> deep</c>
#
# 00:01:59.270 --> 00:01:59.280 align:start position:0%
# of nintendo you'll see these deep
#
#
# 00:01:59.280 --> 00:02:01.270 align:start position:0%
# of nintendo you'll see these deep
# narratives<00:01:59.759><c> set</c><00:01:59.920><c> in</c><00:02:00.079><c> japan</c><00:02:00.560><c> that's</c><00:02:00.799><c> the</c>
#
# 00:02:01.270 --> 00:02:01.280 align:start position:0%
# narratives set in japan that's the
#
#
# 00:02:01.280 --> 00:02:03.270 align:start position:0%
# narratives set in japan that's the
# super<00:02:01.520><c> nintendo</c><00:02:02.079><c> you'll</c><00:02:02.320><c> solve</c><00:02:02.640><c> a</c><00:02:02.719><c> complex</c>
#
# 00:02:03.270 --> 00:02:03.280 align:start position:0%
# super nintendo you'll solve a complex
#
#
# 00:02:03.280 --> 00:02:04.469 align:start position:0%
# super nintendo you'll solve a complex
# murder<00:02:03.520><c> i</c><00:02:03.600><c> gotta</c><00:02:03.759><c> tweet</c><00:02:04.000><c> that</c><00:02:04.079><c> i'm</c><00:02:04.240><c> streaming</c>
#
# 00:02:04.469 --> 00:02:04.479 align:start position:0%
# murder i gotta tweet that i'm streaming
#
#
# 00:02:04.479 --> 00:02:06.310 align:start position:0%
# murder i gotta tweet that i'm streaming
# a<00:02:04.560><c> wealthy</c><00:02:04.880><c> family</c><00:02:05.280><c> in</c><00:02:05.439><c> a</c><00:02:05.520><c> haunted</c><00:02:05.920><c> village</c>
#
# 00:02:06.310 --> 00:02:06.320 align:start position:0%
# a wealthy family in a haunted village
#
#
# 00:02:06.320 --> 00:02:08.550 align:start position:0%
# a wealthy family in a haunted village
# while<00:02:06.560><c> dealing</c><00:02:06.880><c> with</c><00:02:07.119><c> amnesia</c>
#
# 00:02:08.550 --> 00:02:08.560 align:start position:0%
# while dealing with amnesia
#
#
# 00:02:08.560 --> 00:02:11.510 align:start position:0%
# while dealing with amnesia
# i'll<00:02:08.720><c> turn</c><00:02:08.879><c> it</c><00:02:08.959><c> up</c><00:02:10.319><c> but</c><00:02:10.479><c> that's</c><00:02:10.800><c> not</c><00:02:11.039><c> the</c><00:02:11.200><c> only</c>
#
# 00:02:11.510 --> 00:02:11.520 align:start position:0%
# i'll turn it up but that's not the only
#
#
# 00:02:11.520 --> 00:02:14.190 align:start position:0%
# i'll turn it up but that's not the only
# case<00:02:11.760><c> to</c><00:02:12.000><c> crack</c>
#
# 00:02:14.190 --> 00:02:14.200 align:start position:0%
# case to crack
#
#
# 00:02:14.200 --> 00:02:15.670 align:start position:0%
# case to crack
# [Music]
#
# 00:02:15.670 --> 00:02:15.680 align:start position:0%
# [Music]
#
#
# 00:02:15.680 --> 00:02:17.510 align:start position:0%
# [Music]
# put<00:02:15.840><c> the</c><00:02:16.000><c> cam</c><00:02:16.239><c> back</c><00:02:16.480><c> on</c><00:02:16.640><c> hold</c><00:02:16.800><c> on</c><00:02:17.040><c> a</c><00:02:17.120><c> second</c><00:02:17.440><c> i</c>
#
# 00:02:17.510 --> 00:02:17.520 align:start position:0%
# put the cam back on hold on a second i
#
#
# 00:02:17.520 --> 00:02:20.630 align:start position:0%
# put the cam back on hold on a second i
# wasn't<00:02:17.840><c> ready</c><00:02:18.080><c> for</c><00:02:18.160><c> this</c>
#
# 00:02:20.630 --> 00:02:20.640 align:start position:0%
#
#
#
# 00:02:20.640 --> 00:02:24.790 align:start position:0%
#
# why<00:02:20.800><c> did</c>
#
# 00:02:24.790 --> 00:02:24.800 align:start position:0%
#
#
#
# 00:02:24.800 --> 00:02:26.790 align:start position:0%
#
# mysterious<00:02:25.360><c> death</c><00:02:25.680><c> to</c><00:02:25.840><c> free</c><00:02:26.160><c> students</c><00:02:26.560><c> from</c><00:02:26.720><c> a</c>
#
# 00:02:26.790 --> 00:02:26.800 align:start position:0%
# mysterious death to free students from a
#
#
# 00:02:26.800 --> 00:02:28.630 align:start position:0%
# mysterious death to free students from a
# sinister<00:02:27.360><c> nightmare</c>
#
# 00:02:28.630 --> 00:02:28.640 align:start position:0%
# sinister nightmare
#
#
# 00:02:28.640 --> 00:02:30.550 align:start position:0%
# sinister nightmare
# interrogate<00:02:29.200><c> suspects</c><00:02:29.760><c> and</c><00:02:29.920><c> hunt</c><00:02:30.080><c> for</c><00:02:30.239><c> clues</c>
#
# 00:02:30.550 --> 00:02:30.560 align:start position:0%
# interrogate suspects and hunt for clues
#
#
# 00:02:30.560 --> 00:02:31.750 align:start position:0%
# interrogate suspects and hunt for clues
# to<00:02:30.720><c> piece</c><00:02:31.040><c> together</c><00:02:31.360><c> these</c>
#
# 00:02:31.750 --> 00:02:31.760 align:start position:0%
# to piece together these
#
#
# 00:02:31.760 --> 00:02:33.670 align:start position:0%
# to piece together these
# chilling<00:02:32.000><c> conundrums</c><00:02:33.280><c> what</c><00:02:33.440><c> did</c><00:02:33.599><c> they</c>
#
# 00:02:33.670 --> 00:02:33.680 align:start position:0%
# chilling conundrums what did they
#
#
# 00:02:33.680 --> 00:02:38.630 align:start position:0%
# chilling conundrums what did they
# already<00:02:33.840><c> announce</c><00:02:34.160><c> who</c><00:02:34.239><c> the</c><00:02:34.319><c> next</c><00:02:34.560><c> smash</c>
#
# 00:02:38.630 --> 00:02:38.640 align:start position:0%
#
#
#
# 00:02:38.640 --> 00:02:39.589 align:start position:0%
#
# did<00:02:38.720><c> they</c><00:02:38.800><c> announce</c><00:02:39.120><c> who</c><00:02:39.200><c> the</c><00:02:39.280><c> next</c><00:02:39.360><c> smash</c>
#
# 00:02:39.589 --> 00:02:39.599 align:start position:0%
# did they announce who the next smash
#
#
# 00:02:39.599 --> 00:02:41.990 align:start position:0%
# did they announce who the next smash
# brothers<00:02:39.840><c> character</c><00:02:40.160><c> is</c><00:02:41.200><c> they</c><00:02:41.280><c> did</c><00:02:41.599><c> who</c><00:02:41.760><c> was</c>
#
# 00:02:41.990 --> 00:02:42.000 align:start position:0%
# brothers character is they did who was
#
#
# 00:02:42.000 --> 00:02:45.589 align:start position:0%
# brothers character is they did who was
# it
#
# 00:02:45.589 --> 00:02:45.599 align:start position:0%
#
#
#
# 00:02:45.599 --> 00:02:48.229 align:start position:0%
#
# johnny<00:02:45.920><c> bravo</c><00:02:47.200><c> really</c><00:02:47.440><c> hope</c><00:02:47.680><c> it</c><00:02:47.760><c> was</c><00:02:47.920><c> johnny</c>
#
# 00:02:48.229 --> 00:02:48.239 align:start position:0%
# johnny bravo really hope it was johnny
#
#
# 00:02:48.239 --> 00:02:49.110 align:start position:0%
# johnny bravo really hope it was johnny
# bravo
#
# 00:02:49.110 --> 00:02:49.120 align:start position:0%
# bravo
#
#
# 00:02:49.120 --> 00:02:51.030 align:start position:0%
# bravo
# uncover<00:02:49.519><c> the</c><00:02:49.760><c> deadly</c><00:02:50.080><c> truth</c><00:02:50.480><c> and</c><00:02:50.640><c> famicom</c>
#
# 00:02:51.030 --> 00:02:51.040 align:start position:0%
# uncover the deadly truth and famicom
#
#
# 00:02:51.040 --> 00:02:52.790 align:start position:0%
# uncover the deadly truth and famicom
# detective<00:02:51.599><c> club</c><00:02:51.840><c> the</c><00:02:52.000><c> missing</c><00:02:52.319><c> air</c><00:02:52.560><c> who's</c><00:02:52.720><c> a</c>
#
# 00:02:52.790 --> 00:02:52.800 align:start position:0%
# detective club the missing air who's a
#
#
# 00:02:52.800 --> 00:02:53.670 align:start position:0%
# detective club the missing air who's a
# xenoblade
#
# 00:02:53.670 --> 00:02:53.680 align:start position:0%
# xenoblade
#
#
# 00:02:53.680 --> 00:02:55.270 align:start position:0%
# xenoblade
# detective<00:02:54.080><c> club</c><00:02:54.400><c> the</c><00:02:54.480><c> girl</c><00:02:54.720><c> who</c><00:02:54.959><c> stands</c>
#
# 00:02:55.270 --> 00:02:55.280 align:start position:0%
# detective club the girl who stands
#
#
# 00:02:55.280 --> 00:02:57.430 align:start position:0%
# detective club the girl who stands
# behind<00:02:56.080><c> coming</c><00:02:56.319><c> to</c><00:02:56.480><c> nintendo</c><00:02:56.959><c> switch</c>
#
# 00:02:57.430 --> 00:02:57.440 align:start position:0%
# behind coming to nintendo switch
#
#
# 00:02:57.440 --> 00:03:00.070 align:start position:0%
# behind coming to nintendo switch
# may<00:02:57.680><c> 14th</c><00:02:58.640><c> pre-orders</c><00:02:59.200><c> begin</c><00:02:59.519><c> today</c><00:02:59.920><c> on</c>
#
# 00:03:00.070 --> 00:03:00.080 align:start position:0%
# may 14th pre-orders begin today on
#
#
# 00:03:00.080 --> 00:03:04.790 align:start position:0%
# may 14th pre-orders begin today on
# nintendo<00:03:02.840><c> eshop</c>
#
# 00:03:04.790 --> 00:03:04.800 align:start position:0%
# nintendo eshop
#
#
# 00:03:04.800 --> 00:03:07.270 align:start position:0%
# nintendo eshop
# a<00:03:05.040><c> new</c><00:03:05.280><c> age</c><00:03:05.599><c> of</c><00:03:05.840><c> battles</c><00:03:06.319><c> begins</c><00:03:06.720><c> a</c><00:03:06.800><c> new</c><00:03:06.959><c> age</c><00:03:07.200><c> of</c>
#
# 00:03:07.270 --> 00:03:07.280 align:start position:0%
# a new age of battles begins a new age of
#
#
# 00:03:07.280 --> 00:03:07.830 align:start position:0%
# a new age of battles begins a new age of
# bad<00:03:07.440><c> oh</c>
#
# 00:03:07.830 --> 00:03:07.840 align:start position:0%
# bad oh
#
#
# 00:03:07.840 --> 00:03:12.869 align:start position:0%
# bad oh
# i<00:03:07.920><c> gotta</c><00:03:08.080><c> tweet</c><00:03:08.400><c> this</c>
#
# 00:03:12.869 --> 00:03:12.879 align:start position:0%
#
#
#
# 00:03:12.879 --> 00:03:14.229 align:start position:0%
#
# i'm<00:03:13.040><c> not</c><00:03:13.120><c> even</c><00:03:13.280><c> paying</c><00:03:13.440><c> attention</c><00:03:13.920><c> i</c><00:03:14.000><c> care</c>
#
# 00:03:14.229 --> 00:03:14.239 align:start position:0%
# i'm not even paying attention i care
#
#
# 00:03:14.239 --> 00:03:15.750 align:start position:0%
# i'm not even paying attention i care
# more<00:03:14.400><c> about</c><00:03:14.560><c> like</c><00:03:14.720><c> tweeting</c><00:03:15.040><c> my</c><00:03:15.200><c> stream</c><00:03:15.680><c> i'm</c>
#
# 00:03:15.750 --> 00:03:15.760 align:start position:0%
# more about like tweeting my stream i'm
#
#
# 00:03:15.760 --> 00:03:16.070 align:start position:0%
# more about like tweeting my stream i'm
# not
#
# 00:03:16.070 --> 00:03:16.080 align:start position:0%
# not
#
#
# 00:03:16.080 --> 00:03:28.149 align:start position:0%
# not
# what<00:03:16.640><c> hold</c><00:03:16.879><c> on</c>
#
# 00:03:28.149 --> 00:03:28.159 align:start position:0%
#
#
#
# 00:03:28.159 --> 00:03:30.390 align:start position:0%
#
# i'm<00:03:28.400><c> like</c><00:03:28.640><c> screen</c><00:03:29.120><c> capping</c><00:03:29.519><c> this</c><00:03:29.840><c> window</c><00:03:30.239><c> by</c>
#
# 00:03:30.390 --> 00:03:30.400 align:start position:0%
# i'm like screen capping this window by
#
#
# 00:03:30.400 --> 00:03:31.430 align:start position:0%
# i'm like screen capping this window by
# the<00:03:30.480><c> way</c><00:03:30.640><c> i</c><00:03:30.720><c> didn't</c><00:03:30.879><c> even</c><00:03:31.040><c> get</c><00:03:31.120><c> the</c>
#
# 00:03:31.430 --> 00:03:31.440 align:start position:0%
# the way i didn't even get the
#
#
# 00:03:31.440 --> 00:03:33.509 align:start position:0%
# the way i didn't even get the
# i<00:03:31.519><c> didn't</c><00:03:31.680><c> even</c><00:03:31.840><c> get</c><00:03:31.920><c> the</c><00:03:32.080><c> embed</c><00:03:32.480><c> link</c><00:03:33.440><c> it</c>
#
# 00:03:33.509 --> 00:03:33.519 align:start position:0%
# i didn't even get the embed link it
#
#
# 00:03:33.519 --> 00:03:36.149 align:start position:0%
# i didn't even get the embed link it
# wasn't<00:03:33.840><c> my</c><00:03:34.080><c> froggy</c><00:03:34.640><c> sleepy</c><00:03:35.120><c> voice</c>
#
# 00:03:36.149 --> 00:03:36.159 align:start position:0%
# wasn't my froggy sleepy voice
#
#
# 00:03:36.159 --> 00:03:37.350 align:start position:0%
# wasn't my froggy sleepy voice
# it<00:03:36.239><c> sounds</c><00:03:36.480><c> like</c><00:03:36.560><c> i</c><00:03:36.640><c> just</c><00:03:36.799><c> got</c><00:03:36.959><c> up</c><00:03:37.120><c> five</c>
#
# 00:03:37.350 --> 00:03:37.360 align:start position:0%
# it sounds like i just got up five
#
#
# 00:03:37.360 --> 00:03:39.589 align:start position:0%
# it sounds like i just got up five
# minutes<00:03:37.599><c> ago</c><00:03:38.560><c> i</c><00:03:38.720><c> may</c><00:03:38.879><c> have</c>
#
# 00:03:39.589 --> 00:03:39.599 align:start position:0%
# minutes ago i may have
#
#
# 00:03:39.599 --> 00:03:42.869 align:start position:0%
# minutes ago i may have
# i<00:03:39.760><c> got</c>
#
# 00:03:42.869 --> 00:03:42.879 align:start position:0%
#
#
#
# 00:03:42.879 --> 00:03:47.820 align:start position:0%
#
# all<00:03:42.959><c> right</c><00:03:43.040><c> i</c><00:03:43.120><c> got</c><00:03:43.280><c> it's</c><00:03:43.440><c> way</c><00:03:43.599><c> down</c><00:03:43.840><c> i'm</c><00:03:44.840><c> ready</c>
#
# 00:03:47.820 --> 00:03:47.830 align:start position:0%
# all right i got it's way down i'm ready
#
#
# 00:03:47.830 --> 00:03:49.910 align:start position:0%
# all right i got it's way down i'm ready
# [Music]
#
# 00:03:49.910 --> 00:03:49.920 align:start position:0%
# [Music]
#
#
# 00:03:49.920 --> 00:03:53.030 align:start position:0%
# [Music]
# samurai<00:03:50.400><c> warriors</c><00:03:50.879><c> 5</c><00:03:51.920><c> the</c><00:03:52.080><c> latest</c><00:03:52.560><c> entry</c><00:03:52.959><c> in</c>
#
# 00:03:53.030 --> 00:03:53.040 align:start position:0%
# samurai warriors 5 the latest entry in
#
#
# 00:03:53.040 --> 00:03:55.190 align:start position:0%
# samurai warriors 5 the latest entry in
# the<00:03:53.200><c> samurai</c><00:03:53.680><c> warriors</c><00:03:54.159><c> franchise</c><00:03:54.720><c> is</c><00:03:54.879><c> coming</c>
#
# 00:03:55.190 --> 00:03:55.200 align:start position:0%
# the samurai warriors franchise is coming
#
#
# 00:03:55.200 --> 00:03:57.509 align:start position:0%
# the samurai warriors franchise is coming
# to<00:03:55.360><c> nintendo</c><00:03:55.840><c> switch</c>
#
# 00:03:57.509 --> 00:03:57.519 align:start position:0%
# to nintendo switch
#
#
# 00:03:57.519 --> 00:03:59.350 align:start position:0%
# to nintendo switch
# dive<00:03:57.760><c> into</c><00:03:58.000><c> the</c><00:03:58.080><c> history</c><00:03:58.560><c> of</c><00:03:58.640><c> the</c><00:03:58.799><c> sengoku</c>
#
# 00:03:59.350 --> 00:03:59.360 align:start position:0%
# dive into the history of the sengoku
#
#
# 00:03:59.360 --> 00:04:01.350 align:start position:0%
# dive into the history of the sengoku
# period<00:03:59.920><c> as</c><00:04:00.080><c> the</c><00:04:00.239><c> series</c><00:04:00.640><c> now</c><00:04:00.879><c> shines</c><00:04:01.280><c> the</c>
#
# 00:04:01.350 --> 00:04:01.360 align:start position:0%
# period as the series now shines the
#
#
# 00:04:01.360 --> 00:04:05.350 align:start position:0%
# period as the series now shines the
# spotlight<00:04:02.000><c> on</c><00:04:02.159><c> nobunaga</c><00:04:02.959><c> ora</c><00:04:03.280><c> and</c><00:04:03.360><c> mitsuhire</c>
#
# 00:04:05.350 --> 00:04:05.360 align:start position:0%
# spotlight on nobunaga ora and mitsuhire
#
#
# 00:04:05.360 --> 00:04:06.869 align:start position:0%
# spotlight on nobunaga ora and mitsuhire
# i<00:04:05.439><c> have</c><00:04:05.599><c> no</c><00:04:05.840><c> idea</c><00:04:06.080><c> what's</c><00:04:06.319><c> going</c><00:04:06.480><c> on</c><00:04:06.560><c> character</c>
#
# 00:04:06.869 --> 00:04:06.879 align:start position:0%
# i have no idea what's going on character
#
#
# 00:04:06.879 --> 00:04:08.710 align:start position:0%
# i have no idea what's going on character
# designs<00:04:07.360><c> and</c><00:04:07.519><c> visuals</c><00:04:07.920><c> have</c><00:04:08.080><c> been</c><00:04:08.239><c> revamped</c>
#
# 00:04:08.710 --> 00:04:08.720 align:start position:0%
# designs and visuals have been revamped
#
#
# 00:04:08.720 --> 00:04:10.630 align:start position:0%
# designs and visuals have been revamped
# for<00:04:08.799><c> this</c><00:04:09.040><c> installment</c><00:04:09.519><c> like</c><00:04:09.760><c> i'm</c><00:04:09.920><c> dreaming</c>
#
# 00:04:10.630 --> 00:04:10.640 align:start position:0%
# for this installment like i'm dreaming
#
#
# 00:04:10.640 --> 00:04:12.869 align:start position:0%
# for this installment like i'm dreaming
# unleash<00:04:11.120><c> high</c><00:04:11.360><c> octane</c><00:04:11.840><c> i'm</c><00:04:12.159><c> an</c><00:04:12.319><c> electrophile</c>
#
# 00:04:12.869 --> 00:04:12.879 align:start position:0%
# unleash high octane i'm an electrophile
#
#
# 00:04:12.879 --> 00:04:27.189 align:start position:0%
# unleash high octane i'm an electrophile
# i'm
#
# 00:04:27.189 --> 00:04:27.199 align:start position:0%
#
#
#
# 00:04:27.199 --> 00:04:28.950 align:start position:0%
#
# to<00:04:27.280><c> get</c><00:04:27.360><c> a</c><00:04:27.520><c> stream</c><00:04:27.919><c> on</c><00:04:28.080><c> to</c><00:04:28.320><c> to</c><00:04:28.560><c> stream</c><00:04:28.880><c> and</c>
#
# 00:04:28.950 --> 00:04:28.960 align:start position:0%
# to get a stream on to to stream and
#
#
# 00:04:28.960 --> 00:04:30.230 align:start position:0%
# to get a stream on to to stream and
# nintendo<00:04:29.440><c> directed</c><00:04:29.840><c> when</c><00:04:30.000><c> i've</c><00:04:30.080><c> only</c>
#
# 00:04:30.230 --> 00:04:30.240 align:start position:0%
# nintendo directed when i've only
#
#
# 00:04:30.240 --> 00:04:31.830 align:start position:0%
# nintendo directed when i've only
# streamed<00:04:30.560><c> like</c><00:04:30.720><c> one</c><00:04:30.960><c> nintendo</c><00:04:31.360><c> direct</c><00:04:31.600><c> in</c>
#
# 00:04:31.830 --> 00:04:31.840 align:start position:0%
# streamed like one nintendo direct in
#
#
# 00:04:31.840 --> 00:04:34.310 align:start position:0%
# streamed like one nintendo direct in
# four<00:04:32.080><c> years</c><00:04:32.960><c> legend</c><00:04:33.360><c> of</c><00:04:33.520><c> mana</c><00:04:33.840><c> featuring</c>
#
# 00:04:34.310 --> 00:04:34.320 align:start position:0%
# four years legend of mana featuring
#
#
# 00:04:34.320 --> 00:04:36.469 align:start position:0%
# four years legend of mana featuring
# remastered<00:04:35.040><c> hd</c><00:04:35.440><c> graphics</c><00:04:35.919><c> is</c><00:04:36.000><c> coming</c><00:04:36.320><c> to</c>
#
# 00:04:36.469 --> 00:04:36.479 align:start position:0%
# remastered hd graphics is coming to
#
#
# 00:04:36.479 --> 00:04:37.749 align:start position:0%
# remastered hd graphics is coming to
# nintendo<00:04:37.040><c> switch</c>
#
# 00:04:37.749 --> 00:04:37.759 align:start position:0%
# nintendo switch
#
#
# 00:04:37.759 --> 00:04:40.390 align:start position:0%
# nintendo switch
# i<00:04:37.840><c> don't</c><00:04:38.000><c> think</c><00:04:38.080><c> i've</c><00:04:38.240><c> ever</c><00:04:38.400><c> done</c><00:04:38.560><c> this</c><00:04:40.080><c> have</c><00:04:40.240><c> i</c>
#
# 00:04:40.390 --> 00:04:40.400 align:start position:0%
# i don't think i've ever done this have i
#
#
# 00:04:40.400 --> 00:04:42.070 align:start position:0%
# i don't think i've ever done this have i
# ever<00:04:40.560><c> done</c><00:04:40.720><c> this</c><00:04:40.880><c> all</c><00:04:41.040><c> set</c><00:04:41.280><c> off</c><00:04:41.440><c> on</c><00:04:41.600><c> a</c><00:04:41.680><c> journey</c>
#
# 00:04:42.070 --> 00:04:42.080 align:start position:0%
# ever done this all set off on a journey
#
#
# 00:04:42.080 --> 00:04:44.230 align:start position:0%
# ever done this all set off on a journey
# to<00:04:42.240><c> find</c><00:04:42.479><c> the</c><00:04:42.639><c> mystical</c><00:04:43.120><c> mana</c><00:04:43.440><c> tree</c><00:04:43.759><c> seen</c><00:04:44.000><c> in</c><00:04:44.160><c> a</c>
#
# 00:04:44.230 --> 00:04:44.240 align:start position:0%
# to find the mystical mana tree seen in a
#
#
# 00:04:44.240 --> 00:04:46.230 align:start position:0%
# to find the mystical mana tree seen in a
# dream
#
# 00:04:46.230 --> 00:04:46.240 align:start position:0%
# dream
#
#
# 00:04:46.240 --> 00:04:48.230 align:start position:0%
# dream
# i<00:04:46.479><c> this</c><00:04:46.639><c> was</c><00:04:46.800><c> saying</c><00:04:47.120><c> discovering</c><00:04:47.680><c> the</c><00:04:47.840><c> world</c>
#
# 00:04:48.230 --> 00:04:48.240 align:start position:0%
# i this was saying discovering the world
#
#
# 00:04:48.240 --> 00:04:49.990 align:start position:0%
# i this was saying discovering the world
# map<00:04:48.960><c> is</c><00:04:49.120><c> empty</c>
#
# 00:04:49.990 --> 00:04:50.000 align:start position:0%
# map is empty
#
#
# 00:04:50.000 --> 00:04:51.350 align:start position:0%
# map is empty
# first<00:04:50.320><c> the</c><00:04:50.400><c> world's</c><00:04:50.720><c> going</c><00:04:50.800><c> to</c><00:04:50.880><c> explode</c><00:04:51.199><c> then</c>
#
# 00:04:51.350 --> 00:04:51.360 align:start position:0%
# first the world's going to explode then
#
#
# 00:04:51.360 --> 00:04:52.710 align:start position:0%
# first the world's going to explode then
# i'm<00:04:51.440><c> going</c><00:04:51.520><c> to</c><00:04:51.600><c> drain</c><00:04:51.840><c> there's</c><00:04:52.080><c> special</c><00:04:52.400><c> items</c>
#
# 00:04:52.710 --> 00:04:52.720 align:start position:0%
# i'm going to drain there's special items
#
#
# 00:04:52.720 --> 00:04:54.230 align:start position:0%
# i'm going to drain there's special items
# called<00:04:53.040><c> artifacts</c><00:04:53.600><c> oh</c><00:04:53.759><c> [ __ ]</c><00:04:53.919><c> i</c><00:04:54.000><c> got</c><00:04:54.080><c> to</c><00:04:54.080><c> shut</c>
#
# 00:04:54.230 --> 00:04:54.240 align:start position:0%
# called artifacts oh [ __ ] i got to shut
#
#
# 00:04:54.240 --> 00:04:54.710 align:start position:0%
# called artifacts oh [ __ ] i got to shut
# up
#
# 00:04:54.710 --> 00:04:54.720 align:start position:0%
# up
#
#
# 00:04:54.720 --> 00:04:57.110 align:start position:0%
# up
# on<00:04:54.800><c> the</c><00:04:54.880><c> map</c><00:04:55.120><c> to</c><00:04:55.280><c> bring</c><00:04:55.520><c> towns</c><00:04:56.240><c> dungeons</c><00:04:56.960><c> and</c>
#
# 00:04:57.110 --> 00:04:57.120 align:start position:0%
# on the map to bring towns dungeons and
#
#
# 00:04:57.120 --> 00:05:00.230 align:start position:0%
# on the map to bring towns dungeons and
# other<00:04:57.440><c> lands</c><00:04:57.759><c> to</c><00:04:58.000><c> life</c>
#
# 00:05:00.230 --> 00:05:00.240 align:start position:0%
# other lands to life
#
#
# 00:05:00.240 --> 00:05:01.990 align:start position:0%
# other lands to life
# it's<00:05:00.479><c> up</c><00:05:00.639><c> to</c><00:05:00.720><c> you</c><00:05:00.960><c> on</c><00:05:01.199><c> when</c><00:05:01.440><c> and</c><00:05:01.600><c> where</c><00:05:01.840><c> to</c>
#
# 00:05:01.990 --> 00:05:02.000 align:start position:0%
# it's up to you on when and where to
#
#
# 00:05:02.000 --> 00:05:03.990 align:start position:0%
# it's up to you on when and where to
# place<00:05:02.240><c> artifacts</c><00:05:03.120><c> as</c><00:05:03.280><c> well</c><00:05:03.440><c> as</c><00:05:03.600><c> how</c><00:05:03.840><c> to</c>
#
# 00:05:03.990 --> 00:05:04.000 align:start position:0%
# place artifacts as well as how to
#
#
# 00:05:04.000 --> 00:05:08.150 align:start position:0%
# place artifacts as well as how to
# advance<00:05:04.400><c> the</c><00:05:04.560><c> story</c>
#
# 00:05:08.150 --> 00:05:08.160 align:start position:0%
#
#
#
# 00:05:08.160 --> 00:05:10.070 align:start position:0%
#
# join<00:05:08.479><c> forces</c><00:05:08.880><c> with</c><00:05:09.039><c> characters</c><00:05:09.680><c> each</c><00:05:10.000><c> on</c>
#
# 00:05:10.070 --> 00:05:10.080 align:start position:0%
# join forces with characters each on
#
#
# 00:05:10.080 --> 00:05:12.310 align:start position:0%
# join forces with characters each on
# their<00:05:10.320><c> own</c><00:05:10.479><c> personal</c><00:05:10.880><c> quests</c>
#
# 00:05:12.310 --> 00:05:12.320 align:start position:0%
# their own personal quests
#
#
# 00:05:12.320 --> 00:05:16.870 align:start position:0%
# their own personal quests
# square<00:05:12.720><c> off</c><00:05:12.880><c> against</c><00:05:13.280><c> fearsome</c><00:05:13.680><c> monsters</c>
#
# 00:05:16.870 --> 00:05:16.880 align:start position:0%
#
#
#
# 00:05:16.880 --> 00:05:18.629 align:start position:0%
#
# from<00:05:17.039><c> adventure</c><00:05:17.840><c> that</c><00:05:17.919><c> snowman</c><00:05:18.320><c> was</c><00:05:18.479><c> pretty</c>
#
# 00:05:18.629 --> 00:05:18.639 align:start position:0%
# from adventure that snowman was pretty
#
#
# 00:05:18.639 --> 00:05:20.710 align:start position:0%
# from adventure that snowman was pretty
# cool
#
# 00:05:20.710 --> 00:05:20.720 align:start position:0%
# cool
#
#
# 00:05:20.720 --> 00:05:22.710 align:start position:0%
# cool
# okay<00:05:21.280><c> music</c><00:05:21.520><c> has</c><00:05:21.680><c> been</c><00:05:21.840><c> rearranged</c><00:05:22.400><c> for</c><00:05:22.560><c> this</c>
#
# 00:05:22.710 --> 00:05:22.720 align:start position:0%
# okay music has been rearranged for this
#
#
# 00:05:22.720 --> 00:05:24.710 align:start position:0%
# okay music has been rearranged for this
# enhanced<00:05:23.199><c> version</c><00:05:23.919><c> and</c><00:05:24.080><c> you</c><00:05:24.160><c> can</c><00:05:24.320><c> alternate</c>
#
# 00:05:24.710 --> 00:05:24.720 align:start position:0%
# enhanced version and you can alternate
#
#
# 00:05:24.720 --> 00:05:26.150 align:start position:0%
# enhanced version and you can alternate
# between<00:05:25.039><c> the</c><00:05:25.120><c> new</c><00:05:25.280><c> arrangement</c><00:05:25.919><c> and</c><00:05:26.000><c> the</c>
#
# 00:05:26.150 --> 00:05:26.160 align:start position:0%
# between the new arrangement and the
#
#
# 00:05:26.160 --> 00:05:27.670 align:start position:0%
# between the new arrangement and the
# original<00:05:26.560><c> soundtrack</c>
#
# 00:05:27.670 --> 00:05:27.680 align:start position:0%
# original soundtrack
#
#
# 00:05:27.680 --> 00:05:29.590 align:start position:0%
# original soundtrack
# other<00:05:27.919><c> features</c><00:05:28.320><c> have</c><00:05:28.400><c> been</c><00:05:28.560><c> added</c><00:05:29.199><c> including</c>
#
# 00:05:29.590 --> 00:05:29.600 align:start position:0%
# other features have been added including
#
#
# 00:05:29.600 --> 00:05:31.830 align:start position:0%
# other features have been added including
# the<00:05:29.680><c> ability</c><00:05:30.080><c> to</c><00:05:30.240><c> turn</c><00:05:30.400><c> off</c><00:05:30.639><c> enemy</c><00:05:30.960><c> encounters</c>
#
# 00:05:31.830 --> 00:05:31.840 align:start position:0%
# the ability to turn off enemy encounters
#
#
# 00:05:31.840 --> 00:05:33.830 align:start position:0%
# the ability to turn off enemy encounters
# as<00:05:32.000><c> well</c><00:05:32.240><c> as</c><00:05:32.479><c> the</c><00:05:32.560><c> new</c><00:05:32.720><c> mini</c><00:05:33.039><c> game</c><00:05:33.440><c> ring</c><00:05:33.600><c> ring</c>
#
# 00:05:33.830 --> 00:05:33.840 align:start position:0%
# as well as the new mini game ring ring
#
#
# 00:05:33.840 --> 00:05:34.870 align:start position:0%
# as well as the new mini game ring ring
# land
#
# 00:05:34.870 --> 00:05:34.880 align:start position:0%
# land
#
#
# 00:05:34.880 --> 00:05:35.990 align:start position:0%
# land
# that<00:05:35.039><c> looks</c><00:05:35.280><c> kind</c><00:05:35.360><c> of</c><00:05:35.440><c> cool</c><00:05:35.680><c> somebody</c><00:05:35.840><c> said</c>
#
# 00:05:35.990 --> 00:05:36.000 align:start position:0%
# that looks kind of cool somebody said
#
#
# 00:05:36.000 --> 00:05:37.670 align:start position:0%
# that looks kind of cool somebody said
# egg<00:05:36.160><c> yolo</c><00:05:36.400><c> legend</c><00:05:36.720><c> of</c><00:05:36.800><c> mana</c><00:05:37.120><c> will</c><00:05:37.280><c> launch</c><00:05:37.600><c> a</c>
#
# 00:05:37.670 --> 00:05:37.680 align:start position:0%
# egg yolo legend of mana will launch a
#
#
# 00:05:37.680 --> 00:05:39.029 align:start position:0%
# egg yolo legend of mana will launch a
# nintendo<00:05:38.240><c> switch</c>
#
# 00:05:39.029 --> 00:05:39.039 align:start position:0%
# nintendo switch
#
#
# 00:05:39.039 --> 00:05:42.070 align:start position:0%
# nintendo switch
# june<00:05:39.360><c> 24th</c><00:05:40.080><c> when</c><00:05:40.240><c> you</c><00:05:40.320><c> mean</c><00:05:40.720><c> this</c><00:05:41.039><c> egg</c><00:05:41.280><c> yolk</c>
#
# 00:05:42.070 --> 00:05:42.080 align:start position:0%
# june 24th when you mean this egg yolk
#
#
# 00:05:42.080 --> 00:05:43.909 align:start position:0%
# june 24th when you mean this egg yolk
# in<00:05:42.320><c> my</c><00:05:42.560><c> hair</c><00:05:42.960><c> and</c><00:05:43.199><c> you</c><00:05:43.280><c> know</c><00:05:43.360><c> what</c><00:05:43.600><c> here's</c><00:05:43.840><c> the</c>
#
# 00:05:43.909 --> 00:05:43.919 align:start position:0%
# in my hair and you know what here's the
#
#
# 00:05:43.919 --> 00:05:45.430 align:start position:0%
# in my hair and you know what here's the
# proof<00:05:44.160><c> that</c><00:05:44.320><c> i</c><00:05:44.400><c> didn't</c><00:05:44.560><c> brush</c><00:05:44.800><c> my</c><00:05:44.960><c> teeth</c>
#
# 00:05:45.430 --> 00:05:45.440 align:start position:0%
# proof that i didn't brush my teeth
#
#
# 00:05:45.440 --> 00:05:46.950 align:start position:0%
# proof that i didn't brush my teeth
# because<00:05:45.600><c> my</c><00:05:45.840><c> tongue</c><00:05:46.080><c> is</c><00:05:46.160><c> probably</c><00:05:46.400><c> still</c><00:05:46.720><c> blue</c>
#
# 00:05:46.950 --> 00:05:46.960 align:start position:0%
# because my tongue is probably still blue
#
#
# 00:05:46.960 --> 00:05:50.830 align:start position:0%
# because my tongue is probably still blue
# from<00:05:47.120><c> a</c><00:05:47.199><c> blue</c><00:05:47.520><c> drink</c><00:05:47.759><c> i</c><00:05:47.840><c> had</c><00:05:48.080><c> last</c><00:05:48.320><c> night</c>
#
# 00:05:50.830 --> 00:05:50.840 align:start position:0%
#
#
#
# 00:05:50.840 --> 00:05:53.490 align:start position:0%
#
# yup
#
# 00:05:53.490 --> 00:05:53.500 align:start position:0%
# yup
#
#
# 00:05:53.500 --> 00:05:55.909 align:start position:0%
# yup
# [Applause]
#
# 00:05:55.909 --> 00:05:55.919 align:start position:0%
# [Applause]
#
#
# 00:05:55.919 --> 00:05:59.830 align:start position:0%
# [Applause]
# is<00:05:56.080><c> it</c><00:05:57.759><c> yeah</c>
#
# 00:05:59.830 --> 00:05:59.840 align:start position:0%
# is it yeah
#
#
# 00:05:59.840 --> 00:06:07.270 align:start position:0%
# is it yeah
# i<00:06:00.000><c> mean</c><00:06:00.160><c> the</c><00:06:00.319><c> screen</c><00:06:00.720><c> is</c><00:06:04.840><c> blue</c>
#
# 00:06:07.270 --> 00:06:07.280 align:start position:0%
# i mean the screen is blue
#
#
# 00:06:07.280 --> 00:06:11.350 align:start position:0%
# i mean the screen is blue
# why'd<00:06:07.520><c> you</c><00:06:07.600><c> need</c><00:06:07.759><c> to</c><00:06:07.840><c> prove</c><00:06:08.080><c> that</c>
#
# 00:06:11.350 --> 00:06:11.360 align:start position:0%
#
#
#
# 00:06:11.360 --> 00:06:22.550 align:start position:0%
#
# you<00:06:11.600><c> don't</c><00:06:11.840><c> [ __ ]</c><00:06:12.080><c> believe</c><00:06:18.840><c> it</c>
#
# 00:06:22.550 --> 00:06:22.560 align:start position:0%
#
#
#
# 00:06:22.560 --> 00:06:27.189 align:start position:0%
#
# wait<00:06:22.800><c> is</c><00:06:22.960><c> this</c><00:06:23.199><c> monster</c><00:06:23.520><c> on</c><00:06:23.600><c> her</c>
#
# 00:06:27.189 --> 00:06:27.199 align:start position:0%
#
#
#
# 00:06:27.199 --> 00:06:28.629 align:start position:0%
#
# why<00:06:27.360><c> did</c><00:06:27.440><c> they</c><00:06:27.520><c> not</c><00:06:27.759><c> put</c><00:06:28.000><c> the</c><00:06:28.160><c> monster</c><00:06:28.479><c> hunter</c>
#
# 00:06:28.629 --> 00:06:28.639 align:start position:0%
# why did they not put the monster hunter
#
#
# 00:06:28.639 --> 00:06:32.629 align:start position:0%
# why did they not put the monster hunter
# world<00:06:28.960><c> on</c><00:06:29.039><c> the</c><00:06:29.199><c> switch</c>
#
# 00:06:32.629 --> 00:06:32.639 align:start position:0%
#
#
#
# 00:06:32.639 --> 00:06:33.830 align:start position:0%
#
# because<00:06:32.800><c> they</c><00:06:32.880><c> were</c><00:06:33.039><c> making</c><00:06:33.199><c> like</c><00:06:33.440><c> a</c><00:06:33.520><c> switch</c>
#
# 00:06:33.830 --> 00:06:33.840 align:start position:0%
# because they were making like a switch
#
#
# 00:06:33.840 --> 00:06:36.550 align:start position:0%
# because they were making like a switch
# version<00:06:34.160><c> kind</c><00:06:34.319><c> of</c><00:06:34.560><c> i</c><00:06:34.720><c> guess</c>
#
# 00:06:36.550 --> 00:06:36.560 align:start position:0%
# version kind of i guess
#
#
# 00:06:36.560 --> 00:06:39.909 align:start position:0%
# version kind of i guess
# it's<00:06:36.720><c> too</c><00:06:36.960><c> powerful</c>
#
# 00:06:39.909 --> 00:06:39.919 align:start position:0%
#
#
#
# 00:06:39.919 --> 00:06:44.550 align:start position:0%
#
# it<00:06:40.080><c> wouldn't</c><00:06:40.479><c> run</c><00:06:40.880><c> well</c><00:06:41.120><c> this</c><00:06:41.280><c> one</c><00:06:41.440><c> does</c>
#
# 00:06:44.550 --> 00:06:44.560 align:start position:0%
#
#
#
# 00:06:44.560 --> 00:06:47.670 align:start position:0%
#
# elder<00:06:45.520><c> i</c><00:06:45.680><c> have</c><00:06:45.919><c> important</c><00:06:46.319><c> news</c>
#
# 00:06:47.670 --> 00:06:47.680 align:start position:0%
# elder i have important news
#
#
# 00:06:47.680 --> 00:06:50.790 align:start position:0%
# elder i have important news
# so<00:06:47.919><c> it's</c><00:06:48.080><c> finally</c><00:06:48.560><c> beginning</c><00:06:50.160><c> go</c><00:06:50.400><c> assemble</c>
#
# 00:06:50.790 --> 00:06:50.800 align:start position:0%
# so it's finally beginning go assemble
#
#
# 00:06:50.800 --> 00:06:52.790 align:start position:0%
# so it's finally beginning go assemble
# the<00:06:50.960><c> villagers</c>
#
# 00:06:52.790 --> 00:06:52.800 align:start position:0%
# the villagers
#
#
# 00:06:52.800 --> 00:06:55.510 align:start position:0%
# the villagers
# 50<00:06:53.199><c> years</c><00:06:53.440><c> ago</c><00:06:54.160><c> kimura</c><00:06:54.720><c> village</c><00:06:55.039><c> was</c><00:06:55.280><c> attacked</c>
#
# 00:06:55.510 --> 00:06:55.520 align:start position:0%
# 50 years ago kimura village was attacked
#
#
# 00:06:55.520 --> 00:06:58.550 align:start position:0%
# 50 years ago kimura village was attacked
# ...
#
# [[0.13878429]]
# {"start":"00:17:47.520","end":"00:17:48.870"}
#
# [[0.16821787]]
# {"start":"00:17:48.870","end":"00:17:48.880"}
#
# [[0.13803658]]
# {"start":"00:17:48.880","end":"00:17:59.190"}
#
# [[0.17681897]]
# {"start":"00:17:59.190","end":"00:17:59.200"}
#
# [[0.14377487]]
# {"start":"00:17:59.200","end":"00:18:02.470"}
#
# [[0.18009067]]
# {"start":"00:18:02.470","end":"00:18:02.480"}
#
# [[0.16307509]]
# {"start":"00:18:02.480","end":"00:18:06.390"}
#
# [[0.15427646]]
# {"start":"00:18:06.390","end":"00:18:06.400"}
#
# [[0.12241361]]
# {"start":"00:18:06.400","end":"00:18:08.390"}
#
# [[0.07894477]]
# {"start":"00:18:08.390","end":"00:18:08.400"}
#
# [[0.10943484]]
# {"start":"00:18:08.400","end":"00:18:10.630"}
#
# [[0.12866443]]
# {"start":"00:18:10.630","end":"00:18:10.640"}
#
# [[0.15583047]]
# {"start":"00:18:10.640","end":"00:18:12.470"}
#
# [[0.1153616]]
# {"start":"00:18:12.470","end":"00:18:12.480"}
#
# [[0.12867355]]
# {"start":"00:18:12.480","end":"00:18:14.630"}
#
# [[0.21960741]]
# {"start":"00:18:14.630","end":"00:18:14.640"}
#
# [[0.16917896]]
# {"start":"00:18:14.640","end":"00:18:17.350"}
#
# [[0.18405163]]
# {"start":"00:18:17.350","end":"00:18:17.360"}
#
# [[0.15067622]]
# {"start":"00:18:17.360","end":"00:18:19.669"}
#
# [[0.14402741]]
# {"start":"00:18:19.669","end":"00:18:19.679"}
#
# [[0.12564102]]
# {"start":"00:18:19.679","end":"00:18:20.549"}
#
# [[0.14979672]]
# {"start":"00:18:20.549","end":"00:18:20.559"}
#
# [[0.17821583]]
# {"start":"00:18:20.559","end":"00:18:23.909"}
#
# [[0.14850467]]
# {"start":"00:18:23.909","end":"00:18:23.919"}
#
# [[0.11686766]]
# {"start":"00:18:23.919","end":"00:18:26.390"}
#
# [[0.16819423]]
# {"start":"00:18:26.390","end":"00:18:26.400"}
#
# [[0.17107558]]
# {"start":"00:18:26.400","end":"00:18:28.310"}
#
# [[0.12911174]]
# {"start":"00:18:28.310","end":"00:18:28.320"}
#
# [[0.13303405]]
# {"start":"00:18:28.320","end":"00:18:31.350"}
#
# [[0.14852649]]
# {"start":"00:18:31.350","end":"00:18:31.360"}
#
# [[0.12230662]]
# {"start":"00:18:31.360","end":"00:18:32.710"}
#
# [[0.15232119]]
# {"start":"00:18:32.710","end":"00:18:32.720"}
#
# [[0.13218504]]
# {"start":"00:18:32.720","end":"00:18:34.470"}
#
# [[0.12331441]]
# {"start":"00:18:34.470","end":"00:18:34.480"}
#
# [[0.09385413]]
# {"start":"00:18:34.480","end":"00:18:38.549"}
#
# [[0.09552899]]
# {"start":"00:18:38.549","end":"00:18:38.559"}
#
# [[0.16635177]]
# {"start":"00:18:38.559","end":"00:18:40.230"}
#
# [[0.12553534]]
# {"start":"00:18:40.230","end":"00:18:40.240"}
#
# [[0.12204111]]
# {"start":"00:18:40.240","end":"00:18:42.390"}
#
# [[0.16439632]]
# {"start":"00:18:42.390","end":"00:18:42.400"}
#
# [[0.13293931]]
# {"start":"00:18:42.400","end":"00:18:44.710"}
#
# [[0.13044563]]
# {"start":"00:18:44.710","end":"00:18:44.720"}
#
# [[0.13209951]]
# {"start":"00:18:44.720","end":"00:18:46.230"}
#
# [[0.09305003]]
# {"start":"00:18:46.230","end":"00:18:46.240"}
#
# [[0.12766686]]
# {"start":"00:18:46.240","end":"00:18:47.510"}
#
# [[0.15123612]]
# {"start":"00:18:47.510","end":"00:18:47.520"}
#
# [[0.16136992]]
# {"start":"00:18:47.520","end":"00:18:49.029"}
#
# [[0.15695393]]
# {"start":"00:18:49.029","end":"00:18:49.039"}
#
# [[0.13758579]]
# {"start":"00:18:49.039","end":"00:18:50.950"}
#
# [[0.17503303]]
# {"start":"00:18:50.950","end":"00:18:50.960"}
#
# [[0.16179153]]
# {"start":"00:18:50.960","end":"00:18:51.830"}
#
# [[0.12643662]]
# {"start":"00:18:51.830","end":"00:18:51.840"}
#
# [[0.1323713]]
# {"start":"00:18:51.840","end":"00:18:53.270"}
#
# [[0.12553656]]
# {"start":"00:18:53.270","end":"00:18:53.280"}
#
# [[0.17358437]]
# {"start":"00:18:53.280","end":"00:18:54.630"}
#
# [[0.09180349]]
# {"start":"00:18:54.630","end":"00:18:54.640"}
#
# [[0.17462748]]
# {"start":"00:18:54.640","end":"00:18:55.110"}
#
# [[0.09812921]]
# {"start":"00:18:55.110","end":"00:18:55.120"}
#
# [[0.1303013]]
# {"start":"00:18:55.120","end":"00:18:57.350"}
#
# [[0.12471676]]
# {"start":"00:18:57.350","end":"00:18:57.360"}
#
# [[0.15895614]]
# {"start":"00:18:57.360","end":"00:18:58.470"}
#
# [[0.09973523]]
# {"start":"00:18:58.470","end":"00:18:58.480"}
# [[0.14793468]]
# {"start":"00:18:58.480","end":"00:19:00.470"}
#
# [[0.12556982]]
# {"start":"00:19:00.470","end":"00:19:00.480"}
#
# [[0.11559188]]
# {"start":"00:19:00.480","end":"00:19:04.230"}
#
# [[0.16261423]]
# {"start":"00:19:04.230","end":"00:19:04.240"}
#
# [[0.12620884]]
# {"start":"00:19:04.240","end":"00:19:05.669"}
#
# [[0.12469622]]
# {"start":"00:19:05.669","end":"00:19:05.679"}
#
# [[0.15415892]]
# {"start":"00:19:05.679","end":"00:19:07.430"}
#
# [[0.14420724]]
# {"start":"00:19:07.430","end":"00:19:07.440"}
#
# [[0.12004089]]
# {"start":"00:19:07.440","end":"00:19:09.669"}
#
# [[0.13949516]]
# {"start":"00:19:09.669","end":"00:19:09.679"}
#
# [[0.14528134]]
# {"start":"00:19:09.679","end":"00:19:11.270"}
#
# [[0.1260966]]
# {"start":"00:19:11.270","end":"00:19:11.280"}
#
# [[0.08726195]]
# {"start":"00:19:11.280","end":"00:19:16.549"}
#
# [[0.11434788]]
# {"start":"00:19:16.549","end":"00:19:16.559"}
#
# [[0.13308197]]
# {"start":"00:19:16.559","end":"00:19:19.669"}
#
# [[0.1641598]]
# {"start":"00:19:19.669","end":"00:19:19.679"}
#
# [[0.12836847]]
# {"start":"00:19:19.679","end":"00:19:23.110"}
#
# [[0.17551953]]
# {"start":"00:19:23.110","end":"00:19:23.120"}
#
# [[0.13296872]]
# {"start":"00:19:23.120","end":"00:19:27.909"}
#
# [[0.11060423]]
# {"start":"00:19:27.909","end":"00:19:27.919"}
#
# [[0.12987152]]
# {"start":"00:19:27.919","end":"00:19:29.990"}
#
# [[0.1106368]]
# {"start":"00:19:29.990","end":"00:19:30.000"}
#
# [[0.12858152]]
# {"start":"00:19:30.000","end":"00:19:33.029"}
#
# [[0.21152839]]
# {"start":"00:19:33.029","end":"00:19:33.039"}
#
# [[0.10297707]]
# {"start":"00:19:33.039","end":"00:19:36.390"}
#
# [[0.14331132]]
# {"start":"00:19:36.390","end":"00:19:36.400"}
#
# [[0.13022715]]
# {"start":"00:19:36.400","end":"00:19:39.190"}
#
# [[0.11723846]]
# {"start":"00:19:39.190","end":"00:19:39.200"}
#
# [[0.10082853]]
# {"start":"00:19:39.200","end":"00:19:40.630"}
#
# [[0.13747418]]
# {"start":"00:19:40.630","end":"00:19:40.640"}
#
# [[0.14306903]]
# {"start":"00:19:40.640","end":"00:19:43.669"}
#
# [[0.13608208]]
# {"start":"00:19:43.669","end":"00:19:43.679"}
#
# [[0.1127933]]
# {"start":"00:19:43.679","end":"00:19:45.590"}
#
# [[0.118637]]
# {"start":"00:19:45.590","end":"00:19:45.600"}
#
# [[0.22363505]]
# {"start":"00:19:45.600","end":"00:19:47.510"}
#
# [[0.13332206]]
# {"start":"00:19:47.510","end":"00:19:47.520"}
#
# [[0.1110549]]
# {"start":"00:19:47.520","end":"00:19:48.549"}
#
# [[0.1307081]]
# {"start":"00:19:48.549","end":"00:19:48.559"}
#
# [[0.15292168]]
# {"start":"00:19:48.559","end":"00:19:52.070"}
#
# [[0.15239838]]
# {"start":"00:19:52.070","end":"00:19:52.080"}
#
# [[0.1107527]]
# {"start":"00:19:52.080","end":"00:19:53.669"}
#
# [[0.10076863]]
# {"start":"00:19:53.669","end":"00:19:53.679"}
#
# [[0.18701267]]
# {"start":"00:19:53.679","end":"00:19:55.510"}
#
# [[0.13306248]]
# {"start":"00:19:55.510","end":"00:19:55.520"}
#
# [[0.13116309]]
# {"start":"00:19:55.520","end":"00:19:56.549"}
#
# [[0.18613091]]
# {"start":"00:19:56.549","end":"00:19:56.559"}
#
# [[0.14460132]]
# {"start":"00:19:56.559","end":"00:19:58.150"}
#
# [[0.13599303]]
# {"start":"00:19:58.150","end":"00:19:58.160"}
#
# [[0.14490312]]
# {"start":"00:19:58.160","end":"00:19:58.630"}
#
# [[0.21796718]]
# {"start":"00:19:58.630","end":"00:19:58.640"}
#
# [[0.19685072]]
# {"start":"00:19:58.640","end":"00:20:00.390"}
#
# [[0.12758747]]
# {"start":"00:20:00.390","end":"00:20:00.400"}
#
# [[0.16134983]]
# {"start":"00:20:00.400","end":"00:20:02.310"}
#
# [[0.13069826]]
# {"start":"00:20:02.310","end":"00:20:02.320"}
#
# [[0.1315485]]
# {"start":"00:20:02.320","end":"00:20:03.909"}
#
# [[0.17213392]]
# {"start":"00:20:03.909","end":"00:20:03.919"}
#
# [[0.10948041]]
# {"start":"00:20:03.919","end":"00:20:05.990"}
#
# [[0.16947022]]
# {"start":"00:20:05.990","end":"00:20:06.000"}
#
# [[0.13280818]]
# {"start":"00:20:06.000","end":"00:20:07.110"}
#
# [[0.1778109]]
# {"start":"00:20:07.110","end":"00:20:07.120"}
#
# [[0.13390937]]
# {"start":"00:20:07.120","end":"00:20:10.310"}
#
# [[0.12911174]]
# {"start":"00:20:10.310","end":"00:20:10.320"}
#
# [[0.12268797]]
# {"start":"00:20:10.320","end":"00:20:14.870"}
#
# [[0.17278987]]
# {"start":"00:20:14.870","end":"00:20:14.880"}
#
# [[0.07832718]]
# {"start":"00:20:14.880","end":"00:20:16.230"}
#
# [[0.11432555]]
# {"start":"00:20:16.230","end":"00:20:16.240"}
#
# [[0.1358056]]
# {"start":"00:20:16.240","end":"00:20:18.710"}
#
# [[0.13708031]]
# {"start":"00:20:18.710","end":"00:20:18.720"}
#
# [[0.14990789]]
# {"start":"00:20:18.720","end":"00:20:22.549"}
#
# [[0.11925915]]
# {"start":"00:20:22.549","end":"00:20:22.559"}
#
# [[0.10143116]]
# {"start":"00:20:22.559","end":"00:20:24.230"}
#
# [[0.12492749]]
# {"start":"00:20:24.230","end":"00:20:24.240"}
#
# [[0.18821809]]
# {"start":"00:20:24.240","end":"00:20:28.870"}
#
# [[0.1465661]]
# {"start":"00:20:28.870","end":"00:20:28.880"}
#
# [[0.255085]]
# {"start":"00:20:28.880","end":"00:20:30.549"}
#
# [[0.16991994]]
# {"start":"00:20:30.549","end":"00:20:30.559"}
#
# [[0.16249582]]
# {"start":"00:20:30.559","end":"00:20:33.190"}
#
# [[0.14711472]]
# {"start":"00:20:33.190","end":"00:20:33.200"}
#
# [[0.14405859]]
# {"start":"00:20:33.200","end":"00:20:35.029"}
#
# [[0.14760739]]
# {"start":"00:20:35.029","end":"00:20:35.039"}
#
# [[0.15068072]]
# {"start":"00:20:35.039","end":"00:20:36.710"}
#
# [[0.17741227]]
# {"start":"00:20:36.710","end":"00:20:36.720"}
#
# [[0.10192576]]
# {"start":"00:20:36.720","end":"00:20:39.190"}
#
# [[0.12049162]]
# {"start":"00:20:39.190","end":"00:20:39.200"}
#
# [[0.11607939]]
# {"start":"00:20:39.200","end":"00:20:41.590"}
#
# [[0.17625993]]
# {"start":"00:20:41.590","end":"00:20:41.600"}
#
# [[0.13907844]]
# {"start":"00:20:41.600","end":"00:20:43.110"}
#
# [[0.15381107]]
# {"start":"00:20:43.110","end":"00:20:43.120"}
#
# [[0.1094228]]
# {"start":"00:20:43.120","end":"00:20:44.470"}
#
# [[0.14486015]]
# {"start":"00:20:44.470","end":"00:20:44.480"}
#
# [[0.11279339]]
# {"start":"00:20:44.480","end":"00:20:45.750"}
#
# [[0.15610662]]
# {"start":"00:20:45.750","end":"00:20:45.760"}
#
# [[0.14476565]]
# {"start":"00:20:45.760","end":"00:20:50.950"}
#
# [[0.1549949]]
# {"start":"00:20:50.950","end":"00:20:50.960"}
#
# [[0.13533953]]
# {"start":"00:20:50.960","end":"00:20:52.630"}
#
# [[0.12982616]]
# {"start":"00:20:52.630","end":"00:20:52.640"}
#
# [[0.15692472]]
# {"start":"00:20:52.640","end":"00:20:53.990"}
#
# [[0.17473722]]
# {"start":"00:20:53.990","end":"00:20:54.000"}
#
# [[0.16173658]]
# {"start":"00:20:54.000","end":"00:20:57.590"}
#
# [[0.13553452]]
# {"start":"00:20:57.590","end":"00:20:57.600"}
#
# [[0.18074435]]
# {"start":"00:20:57.600","end":"00:20:58.549"}
#
# [[0.1138199]]
# {"start":"00:20:58.549","end":"00:20:58.559"}
#
# [[0.10358962]]
# {"start":"00:20:58.559","end":"00:21:00.230"}
#
# [[0.13296983]]
# {"start":"00:21:00.230","end":"00:21:00.240"}
#
# [[0.17597586]]
# {"start":"00:21:00.240","end":"00:21:00.789"}
#
# [[0.13627893]]
# {"start":"00:21:00.789","end":"00:21:00.799"}
#
# [[0.2001901]]
# {"start":"00:21:00.799","end":"00:21:03.270"}
#
# [[0.2028712]]
# {"start":"00:21:03.270","end":"00:21:03.280"}
#
# [[0.18110543]]
# {"start":"00:21:03.280","end":"00:21:05.909"}
#
# [[0.1358056]]
# {"start":"00:21:05.909","end":"00:21:05.919"}
#
# [[0.1576666]]
# {"start":"00:21:05.919","end":"00:21:07.430"}
#
# [[0.18746579]]
# {"start":"00:21:07.430","end":"00:21:07.440"}
#
# [[0.17833585]]
# {"start":"00:21:07.440","end":"00:21:10.789"}
#
# [[0.13464957]]
# {"start":"00:21:10.789","end":"00:21:10.799"}
#
# [[0.19985545]]
# {"start":"00:21:10.799","end":"00:21:14.070"}
#
# [[0.22876385]]
# {"start":"00:21:14.070","end":"00:21:14.080"}
#
# [[0.15825954]]
# {"start":"00:21:14.080","end":"00:21:16.230"}
#
# [[0.15516302]]
# {"start":"00:21:16.230","end":"00:21:16.240"}
#
# [[0.13371238]]
# {"start":"00:21:16.240","end":"00:21:19.909"}
#
# [[0.16094524]]
# {"start":"00:21:19.909","end":"00:21:19.919"}
#
# [[0.13827771]]
# {"start":"00:21:19.919","end":"00:21:22.230"}
#
# [[0.1486806]]
# {"start":"00:21:22.230","end":"00:21:22.240"}
#
# [[0.12829432]]
# {"start":"00:21:22.240","end":"00:21:25.029"}
#
# [[0.17505825]]
# {"start":"00:21:25.029","end":"00:21:25.039"}
#
# [[0.14702442]]
# {"start":"00:21:25.039","end":"00:21:28.149"}
#
# [[0.16710216]]
# {"start":"00:21:28.149","end":"00:21:28.159"}
#
# [[0.2160866]]
# {"start":"00:21:28.159","end":"00:21:32.710"}
#
# [[0.1368824]]
# {"start":"00:21:32.710","end":"00:21:32.720"}
#
# [[0.24078476]]
# {"start":"00:21:32.720","end":"00:21:36.149"}
#
# [[0.14124611]]
# {"start":"00:21:36.149","end":"00:21:36.159"}
#
# [[0.22615796]]
# {"start":"00:21:36.159","end":"00:21:40.549"}
#
# [[0.15201622]]
# {"start":"00:21:40.549","end":"00:21:40.559"}
#
# [[0.13173011]]
# {"start":"00:21:40.559","end":"00:21:44.690"}
# [[0.20130873]]
# {"start":"00:21:44.690","end":"00:21:44.700"}
#
# [[0.20185417]]
# {"start":"00:21:44.700","end":"00:21:48.870"}
#
# [[0.15190068]]
# {"start":"00:21:48.870","end":"00:21:48.880"}
#
# [[0.17781705]]
# {"start":"00:21:48.880","end":"00:21:54.710"}
#
# [[0.16773024]]
# {"start":"00:21:54.710","end":"00:21:54.720"}
#
# [[0.17932883]]
# {"start":"00:21:54.720","end":"00:21:57.830"}
#
# [[0.17102513]]
# {"start":"00:21:57.830","end":"00:21:57.840"}
#
# [[0.19249201]]
# {"start":"00:21:57.840","end":"00:21:59.190"}
#
# [[0.12726158]]
# {"start":"00:21:59.190","end":"00:21:59.200"}
#
# [[0.1330381]]
# {"start":"00:21:59.200","end":"00:22:03.190"}
#
# [[0.11883762]]
# {"start":"00:22:03.190","end":"00:22:03.200"}
#
# [[0.12774056]]
# {"start":"00:22:03.200","end":"00:22:04.950"}
#
# [[0.12998489]]
# {"start":"00:22:04.950","end":"00:22:04.960"}
#
# [[0.08635595]]
# {"start":"00:22:04.960","end":"00:22:08.070"}
#
# [[0.14267245]]
# {"start":"00:22:08.070","end":"00:22:08.080"}
#
# [[0.14419004]]
# {"start":"00:22:08.080","end":"00:22:10.470"}
#
# [[0.1562731]]
# {"start":"00:22:10.470","end":"00:22:10.480"}
#
# [[0.23693615]]
# {"start":"00:22:10.480","end":"00:22:13.350"}
#
# [[0.16962045]]
# {"start":"00:22:13.350","end":"00:22:13.360"}
#
# [[0.14505878]]
# {"start":"00:22:13.360","end":"00:22:14.070"}
#
# [[0.14532834]]
# {"start":"00:22:14.070","end":"00:22:14.080"}
#
# [[0.13412264]]
# {"start":"00:22:14.080","end":"00:22:15.909"}
#
# [[0.13698381]]
# {"start":"00:22:15.909","end":"00:22:15.919"}
#
# [[0.23660985]]
# {"start":"00:22:15.919","end":"00:22:18.230"}
#
# [[0.16965446]]
# {"start":"00:22:18.230","end":"00:22:18.240"}
#
# [[0.11226428]]
# {"start":"00:22:18.240","end":"00:22:19.909"}
#
# [[0.16510448]]
# {"start":"00:22:19.909","end":"00:22:19.919"}
#
# [[0.14777857]]
# {"start":"00:22:19.919","end":"00:22:21.110"}
#
# [[0.17856407]]
# {"start":"00:22:21.110","end":"00:22:21.120"}
#
# [[0.17512122]]
# {"start":"00:22:21.120","end":"00:22:24.149"}
#
# [[0.17267135]]
# {"start":"00:22:24.149","end":"00:22:24.159"}
#
# [[0.15585274]]
# {"start":"00:22:24.159","end":"00:22:24.549"}
#
# [[0.20356667]]
# {"start":"00:22:24.549","end":"00:22:24.559"}
#
# [[0.19154283]]
# {"start":"00:22:24.559","end":"00:22:28.470"}
#
# [[0.1598582]]
# {"start":"00:22:28.470","end":"00:22:28.480"}
#
# [[0.16724688]]
# {"start":"00:22:28.480","end":"00:22:30.310"}
#
# [[0.19003367]]
# {"start":"00:22:30.310","end":"00:22:30.320"}
#
# [[0.10971406]]
# {"start":"00:22:30.320","end":"00:22:35.830"}
#
# [[0.10366496]]
# {"start":"00:22:35.830","end":"00:22:35.840"}
#
# [[0.1818032]]
# {"start":"00:22:35.840","end":"00:22:39.190"}
#
# [[0.11728767]]
# {"start":"00:22:39.190","end":"00:22:39.200"}
#
# [[0.14741907]]
# {"start":"00:22:39.200","end":"00:22:42.390"}
#
# [[0.14470395]]
# {"start":"00:22:42.390","end":"00:22:42.400"}
#
# [[0.10657817]]
# {"start":"00:22:42.400","end":"00:22:44.310"}
#
# [[0.09609726]]
# {"start":"00:22:44.310","end":"00:22:44.320"}
#
# [[0.14653307]]
# {"start":"00:22:44.320","end":"00:22:46.310"}
#
# [[0.14111325]]
# {"start":"00:22:46.310","end":"00:22:46.320"}
#
# [[0.1483813]]
# {"start":"00:22:46.320","end":"00:22:48.950"}
#
# [[0.13333169]]
# {"start":"00:22:48.950","end":"00:22:48.960"}
#
# [[0.136753]]
# {"start":"00:22:48.960","end":"00:22:51.510"}
#
# [[0.10598466]]
# {"start":"00:22:51.510","end":"00:22:51.520"}
#
# [[0.14844057]]
# {"start":"00:22:51.520","end":"00:22:54.549"}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-3b72824e09f6> in <module>
#       3     timestamp_file_name = createTimestampFile(youtubeID)
#       4     trans_file_name = createTranscriptFile(youtubeID)
# ----> 5     command_file_name = createCommandFile(timestamp_file_name,trans_file_name)
#
# <ipython-input-14-3fa9a9d6f86c> in createCommandFile(timestamp_file_name, trans_file_name)
#      26         time_dic = json.loads(timestamp_allLines[line])
#      27
# ---> 28         if(not trans_allLines[line].strip()):
#      29             continue
#      30
#
# IndexError: list index out of range
